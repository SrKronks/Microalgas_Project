# %% [markdown]
# # Microalgas Project
#
# Notebook de entrada para ejecutar y revisar el pipeline reproducible.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT

# %%
# Ejecuta el pipeline completo desde una celda
import subprocess, sys
subprocess.run([sys.executable, 'main.py'], cwd=PROJECT_ROOT, check=True)

# %%
import pandas as pd
rankings = pd.read_csv(PROJECT_ROOT / 'outputs' / 'rankings' / 'model_rankings.csv')
rankings.head(20)
